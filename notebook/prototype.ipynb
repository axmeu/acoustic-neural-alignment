# %%
import pandas as pd

# %%
df = pd.read_csv("../outputs/table.csv")
df.sample(5)
# Out:
#       speaker_id  sentence_id  repetition phoneme  onset_s  offset_s  \
# 2819          AG   juxtaposer           2       d  0.96657   1.10000
# 11950         MD      tsarine           1       w  2.11000   2.15000
# 12197         MD  cache cache           1       t  0.94000   0.98000
# 7701          DD   juxtaposer           3       f  2.09000   2.24000
# 6501          CB         hier           4       i  0.86065   1.01501
#
#        duration_ms l1_status gender  \
# 2819        133.43        L1      m
# 11950        40.00        L1      m
# 12197        40.00        L1      m
# 7701        150.00        L2      f
# 6501        154.36        L1      m
#
#                                                 wav_path  \
# 2819   /home/onyxia/work/data/wav_et_textgrids/FRcorp...
# 11950  /home/onyxia/work/data/wav_et_textgrids/FRcorp...
# 12197  /home/onyxia/work/data/wav_et_textgrids/FRcorp...
# 7701   /home/onyxia/work/data/wav_et_textgrids/FRcorp...
# ...
